# %%
# !pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
# import all libraries
# Train/Test Libraries

import os
import numpy as np
import tensorflow as tf
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import scikitplot
from sklearn.metrics import roc_curve, auc
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
dataDir = '/kaggle/input/mmds-cxr'
train_x = np.load(dataDir+'/train_images.npy')
train_y = np.load(dataDir+'/train_labels.npy')
test_x = np.load(dataDir+'/test_images.npy')
test_y = np.load(dataDir+'/test_labels.npy')

print('Training Images: {} | Test Images: {}'.format(train_x.shape, test_x.shape))
print('Training Labels: {} | Test Labels: {}'.format(train_y.shape, test_y.shape))

# Data Normalization

print('Train: {} , {} | Test: {} , {}'.format(train_x.min(), train_x.max(), test_x.min(), test_x.max()))

train_x/=255.0
test_x/=255.0

print('Train: {} , {} | Test: {} , {}'.format(train_x.min(), train_x.max(), test_x.min(), test_x.max()))
# Out:
# Training Images: (14925, 224, 224, 3) | Test Images: (231, 224, 224, 3)
# Training Labels: (14925,) | Test Labels: (231,)
# Train: 0.0 , 255.0 | Test: 0.0 , 255.0
# Train: 0.0 , 1.0 | Test: 0.0 , 1.0

# %%
# Class Mapping 
print('0:Normal | 1:Pneumonia | 2:COVID-19')

# Distribution of images in each class for Training-set
print(Counter(train_y))

# Distribution of images in each class for Test-set
print(Counter(test_y))

#Make Labels Categorical
train_y_oneHot = tf.one_hot(train_y, depth=3) 
test_y_oneHot = tf.one_hot(test_y, depth=3)

print('Training Labels: {} | Test Labels: {}'.format(train_y_oneHot.shape, test_y_oneHot.shape))
# Out:
# 0:Normal | 1:Pneumonia | 2:COVID-19
# Counter({0: 8751, 1: 5945, 2: 229})
# Counter({0: 100, 1: 100, 2: 31})
# Training Labels: (14925, 3) | Test Labels: (231, 3)

# %%
# initialize the training data augmentation object
trainAug = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=15, fill_mode="nearest")

def EfficientNetV2M_Model():
    # load the VGG16 network, ensuring the head FC layer sets are left off
    baseModel = tf.keras.applications.efficientnet_v2.EfficientNetV2M(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
    # construct the head of the model that will be placed on top of the the base model
    output = baseModel.output
    output = tf.keras.layers.GlobalAveragePooling2D()(output)
    output = tf.keras.layers.Dense(1280, activation="relu")(output)
    output = tf.keras.layers.Dense(640, activation="relu")(output)
    output = tf.keras.layers.Dense(3, activation="softmax")(output)
    # place the head FC model on top of the base model (this will become the actual model we will train)
    model = tf.keras.Model(inputs=baseModel.input, outputs=output)
    # loop over all layers in the base model and freeze them so they will not be updated during the first training process
    for layer in baseModel.layers:
        layer.trainable = False
    return model

model = EfficientNetV2M_Model()
# compile our model
print("[INFO] compiling model...")
# initialize the initial learning rate, number of epochs to train for, and batch size
INIT_LR = 0.00085
EPOCHS = 50
BATCHSIZE = 32 
optimizer = tf.keras.optimizers.Adam(lr=INIT_LR, weight_decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.AUC()])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step
# [INFO] compiling model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  stem_conv (Conv2D)          (None, 112, 112, 24)         648       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 112, 112, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block1c_project_conv (Conv  (None, 112, 112, 24)         5184      ['block1b_add[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_project_activation  (None, 112, 112, 24)         0         ['block1c_project_bn[0][0]']
#   (Activation)
#
#  block1c_drop (Dropout)      (None, 112, 112, 24)         0         ['block1c_project_activation[0
#                                                                     ][0]']
#
#  block1c_add (Add)           (None, 112, 112, 24)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 96)           20736     ['block1c_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 56, 56, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 56, 56, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 56, 56, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 56, 56, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 56, 56, 192)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_project_conv (Conv  (None, 56, 56, 48)           9216      ['block2e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2e_project_bn (BatchN  (None, 56, 56, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 56, 56, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 56, 56, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 192)          82944     ['block2e_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 80)           15360     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 320)          230400    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 320)          1280      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 320)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 80)           25600     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 80)           320       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 80)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 80)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 320)          230400    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 320)          1280      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 320)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 80)           25600     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 80)           320       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 80)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 80)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 28, 28, 320)          230400    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 28, 28, 320)          1280      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 28, 28, 320)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 28, 28, 80)           25600     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 28, 28, 80)           320       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 28, 28, 80)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 28, 28, 80)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2  (None, 28, 28, 320)          230400    ['block3d_add[0][0]']
#  D)
#
#  block3e_expand_bn (BatchNo  (None, 28, 28, 320)          1280      ['block3e_expand_conv[0][0]']
#  rmalization)
#
#  block3e_expand_activation   (None, 28, 28, 320)          0         ['block3e_expand_bn[0][0]']
#  (Activation)
#
#  block3e_project_conv (Conv  (None, 28, 28, 80)           25600     ['block3e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3e_project_bn (BatchN  (None, 28, 28, 80)           320       ['block3e_project_conv[0][0]']
#  ormalization)
#
#  block3e_drop (Dropout)      (None, 28, 28, 80)           0         ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)           (None, 28, 28, 80)           0         ['block3e_drop[0][0]',
#                                                                      'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 320)          25600     ['block3e_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 320)          1280      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 320)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 320)          2880      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 320)          1280      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 320)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 320)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 320)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 20)             6420      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 320)            6720      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 320)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 160)          51200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 160)          640       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 640)          102400    ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 640)          2560      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 640)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 640)          5760      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 640)          2560      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 640)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 640)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 640)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 160)          102400    ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 160)          640       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 160)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 160)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 640)          102400    ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 640)          2560      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 640)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 640)          5760      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 640)          2560      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 640)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 640)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 640)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 160)          102400    ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 160)          640       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 160)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 160)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 640)          102400    ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 640)          2560      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 640)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 640)          5760      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 640)          2560      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 640)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 640)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 14, 14, 640)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 14, 14, 160)          102400    ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 14, 14, 160)          640       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 14, 14, 160)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 14, 14, 160)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 14, 14, 640)          102400    ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 14, 14, 640)          2560      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 14, 14, 640)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 14, 14, 640)          5760      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 14, 14, 640)          2560      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 14, 14, 640)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 640)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 14, 14, 640)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 14, 14, 160)          102400    ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 14, 14, 160)          640       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 14, 14, 160)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 14, 14, 160)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 14, 14, 640)          102400    ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 14, 14, 640)          2560      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 14, 14, 640)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 14, 14, 640)          5760      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 14, 14, 640)          2560      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 14, 14, 640)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 640)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 14, 14, 640)          0         ['block4f_activation[0][0]',
# ...
#  block7b_se_excite (Multipl  (None, 7, 7, 3072)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 7, 7, 512)            1572864   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 7, 7, 512)            2048      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 7, 7, 512)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 7, 7, 512)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 7, 7, 3072)           1572864   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 7, 7, 3072)           12288     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 7, 7, 3072)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv2 (Depthwise  (None, 7, 7, 3072)           27648     ['block7c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7c_bn (BatchNormaliza  (None, 7, 7, 3072)           12288     ['block7c_dwconv2[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 7, 7, 3072)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3072)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 7, 7, 3072)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 7, 7, 512)            1572864   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 7, 7, 512)            2048      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 7, 7, 512)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 7, 7, 512)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 7, 7, 3072)           1572864   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 7, 7, 3072)           12288     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 7, 7, 3072)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv2 (Depthwise  (None, 7, 7, 3072)           27648     ['block7d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7d_bn (BatchNormaliza  (None, 7, 7, 3072)           12288     ['block7d_dwconv2[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 7, 7, 3072)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3072)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 7, 7, 3072)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 7, 7, 512)            1572864   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 7, 7, 512)            2048      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 7, 7, 512)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 7, 7, 512)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2  (None, 7, 7, 3072)           1572864   ['block7d_add[0][0]']
#  D)
#
#  block7e_expand_bn (BatchNo  (None, 7, 7, 3072)           12288     ['block7e_expand_conv[0][0]']
#  rmalization)
#
#  block7e_expand_activation   (None, 7, 7, 3072)           0         ['block7e_expand_bn[0][0]']
#  (Activation)
#
#  block7e_dwconv2 (Depthwise  (None, 7, 7, 3072)           27648     ['block7e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7e_bn (BatchNormaliza  (None, 7, 7, 3072)           12288     ['block7e_dwconv2[0][0]']
#  tion)
#
#  block7e_activation (Activa  (None, 7, 7, 3072)           0         ['block7e_bn[0][0]']
#  tion)
#
#  block7e_se_squeeze (Global  (None, 3072)                 0         ['block7e_activation[0][0]']
#  AveragePooling2D)
#
#  block7e_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7e_se_squeeze[0][0]']
#  e)
#
#  block7e_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multipl  (None, 7, 7, 3072)           0         ['block7e_activation[0][0]',
#  y)                                                                  'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv  (None, 7, 7, 512)            1572864   ['block7e_se_excite[0][0]']
#  2D)
#
#  block7e_project_bn (BatchN  (None, 7, 7, 512)            2048      ['block7e_project_conv[0][0]']
#  ormalization)
#
#  block7e_drop (Dropout)      (None, 7, 7, 512)            0         ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)           (None, 7, 7, 512)            0         ['block7e_drop[0][0]',
#                                                                      'block7d_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           655360    ['block7e_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1280)                 1639680   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 640)                  819840    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3)                    1923      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 55611831 (212.14 MB)
# Trainable params: 2461443 (9.39 MB)
# Non-trainable params: 53150388 (202.75 MB)
# __________________________________________________________________________________________________
# None

# %%
modelPath = '/kaggle/working/Model'
if not os.path.exists(modelPath):
    os.makedirs(modelPath)
    print('Model Directory Created')
else:
    print('Model Directory Already Exists')

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(modelPath+'/efficientnetv2-best-model.h5', monitor='val_categorical_accuracy',
                                                      verbose=1, save_best_only=True, mode='auto')

STEP_TRAIN = len(train_x) // BATCHSIZE
STEP_TEST = len(test_x) // BATCHSIZE
modelHistory = model.fit(trainAug.flow(train_x, train_y_oneHot, batch_size=BATCHSIZE), epochs=EPOCHS, verbose=1, callbacks=[model_checkpoint],
                         validation_data=(test_x, test_y_oneHot), shuffle = True, steps_per_epoch=STEP_TRAIN, validation_steps=STEP_TEST)
tf.keras.models.save_model(model, modelPath+'/efficientnetv2-model.h5', overwrite=True, include_optimizer=True, save_format=None,
                           signatures=None, options=None)
# Out:
# Model Directory Created
# Epoch 1/50
# 2023-12-21 13:46:32.309235: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 466/466 [==============================] - ETA: 0s - loss: 0.7576 - categorical_accuracy: 0.5742 - auc: 0.7858
# Epoch 1: val_categorical_accuracy improved from -inf to 0.43290, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 466/466 [==============================] - 198s 361ms/step - loss: 0.7576 - categorical_accuracy: 0.5742 - auc: 0.7858 - val_loss: 1.3162 - val_categorical_accuracy: 0.4329 - val_auc: 0.6635
# Epoch 2/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7463 - categorical_accuracy: 0.5867 - auc: 0.7930
# Epoch 2: val_categorical_accuracy did not improve from 0.43290
# 466/466 [==============================] - 161s 345ms/step - loss: 0.7463 - categorical_accuracy: 0.5867 - auc: 0.7930 - val_loss: 1.2937 - val_categorical_accuracy: 0.4329 - val_auc: 0.6822
# Epoch 3/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7434 - categorical_accuracy: 0.5870 - auc: 0.7970
# Epoch 3: val_categorical_accuracy improved from 0.43290 to 0.44156, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# 466/466 [==============================] - 162s 346ms/step - loss: 0.7434 - categorical_accuracy: 0.5870 - auc: 0.7970 - val_loss: 1.2133 - val_categorical_accuracy: 0.4416 - val_auc: 0.6875
# Epoch 4/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7368 - categorical_accuracy: 0.5973 - auc: 0.8050
# Epoch 4: val_categorical_accuracy improved from 0.44156 to 0.51082, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# 466/466 [==============================] - 161s 346ms/step - loss: 0.7368 - categorical_accuracy: 0.5973 - auc: 0.8050 - val_loss: 1.1506 - val_categorical_accuracy: 0.5108 - val_auc: 0.7031
# Epoch 5/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7317 - categorical_accuracy: 0.6028 - auc: 0.8100
# Epoch 5: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 161s 345ms/step - loss: 0.7317 - categorical_accuracy: 0.6028 - auc: 0.8100 - val_loss: 1.1714 - val_categorical_accuracy: 0.4459 - val_auc: 0.6988
# Epoch 6/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7257 - categorical_accuracy: 0.6069 - auc: 0.8160
# Epoch 6: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 159s 342ms/step - loss: 0.7257 - categorical_accuracy: 0.6069 - auc: 0.8160 - val_loss: 1.1342 - val_categorical_accuracy: 0.5022 - val_auc: 0.7126
# Epoch 7/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7198 - categorical_accuracy: 0.6168 - auc: 0.8210
# Epoch 7: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 161s 346ms/step - loss: 0.7198 - categorical_accuracy: 0.6168 - auc: 0.8210 - val_loss: 1.1353 - val_categorical_accuracy: 0.5108 - val_auc: 0.7146
# Epoch 8/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7178 - categorical_accuracy: 0.6183 - auc: 0.8236
# Epoch 8: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 160s 343ms/step - loss: 0.7178 - categorical_accuracy: 0.6183 - auc: 0.8236 - val_loss: 1.1058 - val_categorical_accuracy: 0.4762 - val_auc: 0.7089
# Epoch 9/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7151 - categorical_accuracy: 0.6228 - auc: 0.8255
# Epoch 9: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 160s 342ms/step - loss: 0.7151 - categorical_accuracy: 0.6228 - auc: 0.8255 - val_loss: 1.1618 - val_categorical_accuracy: 0.4805 - val_auc: 0.7073
# Epoch 10/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7142 - categorical_accuracy: 0.6265 - auc: 0.8264
# Epoch 10: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 161s 344ms/step - loss: 0.7142 - categorical_accuracy: 0.6265 - auc: 0.8264 - val_loss: 1.1103 - val_categorical_accuracy: 0.5022 - val_auc: 0.7142
# Epoch 11/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7153 - categorical_accuracy: 0.6212 - auc: 0.8244
# Epoch 11: val_categorical_accuracy did not improve from 0.51082
# 466/466 [==============================] - 159s 341ms/step - loss: 0.7153 - categorical_accuracy: 0.6212 - auc: 0.8244 - val_loss: 1.1338 - val_categorical_accuracy: 0.4762 - val_auc: 0.7108
# Epoch 12/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7133 - categorical_accuracy: 0.6226 - auc: 0.8264
# Epoch 12: val_categorical_accuracy improved from 0.51082 to 0.53247, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# 466/466 [==============================] - 161s 345ms/step - loss: 0.7133 - categorical_accuracy: 0.6226 - auc: 0.8264 - val_loss: 1.1480 - val_categorical_accuracy: 0.5325 - val_auc: 0.7280
# Epoch 13/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7056 - categorical_accuracy: 0.6293 - auc: 0.8329
# Epoch 13: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 161s 345ms/step - loss: 0.7056 - categorical_accuracy: 0.6293 - auc: 0.8329 - val_loss: 1.2740 - val_categorical_accuracy: 0.5238 - val_auc: 0.7251
# Epoch 14/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7059 - categorical_accuracy: 0.6367 - auc: 0.8332
# Epoch 14: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 160s 344ms/step - loss: 0.7059 - categorical_accuracy: 0.6367 - auc: 0.8332 - val_loss: 1.1894 - val_categorical_accuracy: 0.4719 - val_auc: 0.7076
# Epoch 15/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7070 - categorical_accuracy: 0.6320 - auc: 0.8316
# Epoch 15: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 160s 343ms/step - loss: 0.7070 - categorical_accuracy: 0.6320 - auc: 0.8316 - val_loss: 1.0970 - val_categorical_accuracy: 0.5238 - val_auc: 0.7302
# Epoch 16/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7045 - categorical_accuracy: 0.6353 - auc: 0.8336
# Epoch 16: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 161s 346ms/step - loss: 0.7045 - categorical_accuracy: 0.6353 - auc: 0.8336 - val_loss: 1.2783 - val_categorical_accuracy: 0.4675 - val_auc: 0.7075
# Epoch 17/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7054 - categorical_accuracy: 0.6320 - auc: 0.8333
# Epoch 17: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 161s 346ms/step - loss: 0.7054 - categorical_accuracy: 0.6320 - auc: 0.8333 - val_loss: 1.1012 - val_categorical_accuracy: 0.5152 - val_auc: 0.7333
# Epoch 18/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7006 - categorical_accuracy: 0.6384 - auc: 0.8366
# Epoch 18: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 162s 347ms/step - loss: 0.7006 - categorical_accuracy: 0.6384 - auc: 0.8366 - val_loss: 1.1711 - val_categorical_accuracy: 0.5195 - val_auc: 0.7225
# Epoch 19/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7019 - categorical_accuracy: 0.6399 - auc: 0.8361
# Epoch 19: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 161s 345ms/step - loss: 0.7019 - categorical_accuracy: 0.6399 - auc: 0.8361 - val_loss: 1.1245 - val_categorical_accuracy: 0.5022 - val_auc: 0.7153
# Epoch 20/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7003 - categorical_accuracy: 0.6416 - auc: 0.8379
# Epoch 20: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 162s 348ms/step - loss: 0.7003 - categorical_accuracy: 0.6416 - auc: 0.8379 - val_loss: 1.1719 - val_categorical_accuracy: 0.4978 - val_auc: 0.7108
# Epoch 21/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6993 - categorical_accuracy: 0.6395 - auc: 0.8375
# Epoch 21: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 164s 351ms/step - loss: 0.6993 - categorical_accuracy: 0.6395 - auc: 0.8375 - val_loss: 1.2096 - val_categorical_accuracy: 0.4675 - val_auc: 0.7084
# Epoch 22/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6968 - categorical_accuracy: 0.6467 - auc: 0.8401
# Epoch 22: val_categorical_accuracy did not improve from 0.53247
# 466/466 [==============================] - 163s 349ms/step - loss: 0.6968 - categorical_accuracy: 0.6467 - auc: 0.8401 - val_loss: 1.1709 - val_categorical_accuracy: 0.5022 - val_auc: 0.7159
# Epoch 23/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6972 - categorical_accuracy: 0.6444 - auc: 0.8397
# Epoch 23: val_categorical_accuracy improved from 0.53247 to 0.53680, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# 466/466 [==============================] - 166s 355ms/step - loss: 0.6972 - categorical_accuracy: 0.6444 - auc: 0.8397 - val_loss: 1.1107 - val_categorical_accuracy: 0.5368 - val_auc: 0.7366
# Epoch 24/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6966 - categorical_accuracy: 0.6421 - auc: 0.8395
# Epoch 24: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 164s 351ms/step - loss: 0.6966 - categorical_accuracy: 0.6421 - auc: 0.8395 - val_loss: 1.0801 - val_categorical_accuracy: 0.5195 - val_auc: 0.7257
# Epoch 25/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6971 - categorical_accuracy: 0.6439 - auc: 0.8395
# Epoch 25: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 162s 347ms/step - loss: 0.6971 - categorical_accuracy: 0.6439 - auc: 0.8395 - val_loss: 1.1734 - val_categorical_accuracy: 0.5108 - val_auc: 0.7220
# Epoch 26/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6951 - categorical_accuracy: 0.6429 - auc: 0.8408
# Epoch 26: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 161s 346ms/step - loss: 0.6951 - categorical_accuracy: 0.6429 - auc: 0.8408 - val_loss: 1.0958 - val_categorical_accuracy: 0.5325 - val_auc: 0.7348
# Epoch 27/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6972 - categorical_accuracy: 0.6409 - auc: 0.8391
# Epoch 27: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 162s 347ms/step - loss: 0.6972 - categorical_accuracy: 0.6409 - auc: 0.8391 - val_loss: 1.1220 - val_categorical_accuracy: 0.5238 - val_auc: 0.7243
# Epoch 28/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6900 - categorical_accuracy: 0.6525 - auc: 0.8449
# Epoch 28: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 161s 345ms/step - loss: 0.6900 - categorical_accuracy: 0.6525 - auc: 0.8449 - val_loss: 1.2247 - val_categorical_accuracy: 0.5065 - val_auc: 0.7232
# Epoch 29/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6907 - categorical_accuracy: 0.6499 - auc: 0.8439
# Epoch 29: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 162s 348ms/step - loss: 0.6907 - categorical_accuracy: 0.6499 - auc: 0.8439 - val_loss: 1.1623 - val_categorical_accuracy: 0.5108 - val_auc: 0.7261
# Epoch 30/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6941 - categorical_accuracy: 0.6443 - auc: 0.8417
# Epoch 30: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 161s 345ms/step - loss: 0.6941 - categorical_accuracy: 0.6443 - auc: 0.8417 - val_loss: 1.1519 - val_categorical_accuracy: 0.5238 - val_auc: 0.7303
# Epoch 31/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6935 - categorical_accuracy: 0.6456 - auc: 0.8420
# Epoch 31: val_categorical_accuracy did not improve from 0.53680
# 466/466 [==============================] - 160s 344ms/step - loss: 0.6935 - categorical_accuracy: 0.6456 - auc: 0.8420 - val_loss: 1.1585 - val_categorical_accuracy: 0.5065 - val_auc: 0.7202
# Epoch 32/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6918 - categorical_accuracy: 0.6467 - auc: 0.8429
# Epoch 32: val_categorical_accuracy improved from 0.53680 to 0.59307, saving model to /kaggle/working/Model/efficientnetv2-best-model.h5
# 466/466 [==============================] - 166s 355ms/step - loss: 0.6918 - categorical_accuracy: 0.6467 - auc: 0.8429 - val_loss: 1.0709 - val_categorical_accuracy: 0.5931 - val_auc: 0.7656
# Epoch 33/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6878 - categorical_accuracy: 0.6523 - auc: 0.8461
# Epoch 33: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 164s 352ms/step - loss: 0.6878 - categorical_accuracy: 0.6523 - auc: 0.8461 - val_loss: 1.0877 - val_categorical_accuracy: 0.5368 - val_auc: 0.7378
# Epoch 34/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6919 - categorical_accuracy: 0.6491 - auc: 0.8430
# Epoch 34: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 163s 350ms/step - loss: 0.6919 - categorical_accuracy: 0.6491 - auc: 0.8430 - val_loss: 1.2170 - val_categorical_accuracy: 0.5108 - val_auc: 0.7243
# Epoch 35/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6895 - categorical_accuracy: 0.6514 - auc: 0.8451
# Epoch 35: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 163s 349ms/step - loss: 0.6895 - categorical_accuracy: 0.6514 - auc: 0.8451 - val_loss: 1.2018 - val_categorical_accuracy: 0.5065 - val_auc: 0.7228
# Epoch 36/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6885 - categorical_accuracy: 0.6533 - auc: 0.8457
# Epoch 36: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 162s 348ms/step - loss: 0.6885 - categorical_accuracy: 0.6533 - auc: 0.8457 - val_loss: 1.1009 - val_categorical_accuracy: 0.5455 - val_auc: 0.7381
# Epoch 37/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6867 - categorical_accuracy: 0.6540 - auc: 0.8468
# Epoch 37: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 163s 349ms/step - loss: 0.6867 - categorical_accuracy: 0.6540 - auc: 0.8468 - val_loss: 1.1816 - val_categorical_accuracy: 0.5152 - val_auc: 0.7249
# Epoch 38/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6882 - categorical_accuracy: 0.6490 - auc: 0.8455
# Epoch 38: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 344ms/step - loss: 0.6882 - categorical_accuracy: 0.6490 - auc: 0.8455 - val_loss: 1.1132 - val_categorical_accuracy: 0.5455 - val_auc: 0.7385
# Epoch 39/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6926 - categorical_accuracy: 0.6454 - auc: 0.8419
# Epoch 39: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 345ms/step - loss: 0.6926 - categorical_accuracy: 0.6454 - auc: 0.8419 - val_loss: 1.1216 - val_categorical_accuracy: 0.5411 - val_auc: 0.7394
# Epoch 40/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6828 - categorical_accuracy: 0.6596 - auc: 0.8496
# Epoch 40: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 162s 346ms/step - loss: 0.6828 - categorical_accuracy: 0.6596 - auc: 0.8496 - val_loss: 1.1429 - val_categorical_accuracy: 0.5455 - val_auc: 0.7378
# Epoch 41/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6916 - categorical_accuracy: 0.6525 - auc: 0.8430
# Epoch 41: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 162s 347ms/step - loss: 0.6916 - categorical_accuracy: 0.6525 - auc: 0.8430 - val_loss: 1.1951 - val_categorical_accuracy: 0.4805 - val_auc: 0.7188
# Epoch 42/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6847 - categorical_accuracy: 0.6562 - auc: 0.8479
# Epoch 42: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 162s 348ms/step - loss: 0.6847 - categorical_accuracy: 0.6562 - auc: 0.8479 - val_loss: 1.1349 - val_categorical_accuracy: 0.5411 - val_auc: 0.7385
# Epoch 43/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6865 - categorical_accuracy: 0.6557 - auc: 0.8464
# Epoch 43: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 160s 344ms/step - loss: 0.6865 - categorical_accuracy: 0.6557 - auc: 0.8464 - val_loss: 1.1057 - val_categorical_accuracy: 0.5411 - val_auc: 0.7314
# Epoch 44/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6876 - categorical_accuracy: 0.6529 - auc: 0.8458
# Epoch 44: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 346ms/step - loss: 0.6876 - categorical_accuracy: 0.6529 - auc: 0.8458 - val_loss: 1.1045 - val_categorical_accuracy: 0.5455 - val_auc: 0.7438
# Epoch 45/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6878 - categorical_accuracy: 0.6568 - auc: 0.8459
# Epoch 45: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 345ms/step - loss: 0.6878 - categorical_accuracy: 0.6568 - auc: 0.8459 - val_loss: 1.1970 - val_categorical_accuracy: 0.5108 - val_auc: 0.7210
# Epoch 46/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6834 - categorical_accuracy: 0.6596 - auc: 0.8494
# Epoch 46: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 345ms/step - loss: 0.6834 - categorical_accuracy: 0.6596 - auc: 0.8494 - val_loss: 1.2164 - val_categorical_accuracy: 0.4848 - val_auc: 0.7176
# Epoch 47/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6846 - categorical_accuracy: 0.6581 - auc: 0.8481
# Epoch 47: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 160s 343ms/step - loss: 0.6846 - categorical_accuracy: 0.6581 - auc: 0.8481 - val_loss: 1.1620 - val_categorical_accuracy: 0.4762 - val_auc: 0.7200
# Epoch 48/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6819 - categorical_accuracy: 0.6595 - auc: 0.8498
# Epoch 48: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 160s 342ms/step - loss: 0.6819 - categorical_accuracy: 0.6595 - auc: 0.8498 - val_loss: 1.0505 - val_categorical_accuracy: 0.5541 - val_auc: 0.7387
# Epoch 49/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6798 - categorical_accuracy: 0.6600 - auc: 0.8509
# Epoch 49: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 161s 344ms/step - loss: 0.6798 - categorical_accuracy: 0.6600 - auc: 0.8509 - val_loss: 1.1126 - val_categorical_accuracy: 0.5368 - val_auc: 0.7349
# Epoch 50/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6813 - categorical_accuracy: 0.6598 - auc: 0.8507
# Epoch 50: val_categorical_accuracy did not improve from 0.59307
# 466/466 [==============================] - 160s 342ms/step - loss: 0.6813 - categorical_accuracy: 0.6598 - auc: 0.8507 - val_loss: 1.1446 - val_categorical_accuracy: 0.5065 - val_auc: 0.7285
# /tmp/ipykernel_88/3475908638.py:15: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   tf.keras.models.save_model(model, modelPath+'/efficientnetv2-model.h5', overwrite=True, include_optimizer=True, save_format=None,

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
import matplotlib.pyplot as plt
losshistoryPath = './Train-Test History/Loss'
acchistoryPath = './Train-Test History/Accuracy'
if not os.path.exists(losshistoryPath) or not os.path.exists(acchistoryPath):
    os.makedirs(losshistoryPath)
    os.makedirs(acchistoryPath)
  
# Plot history: Loss
plt.plot(modelHistory.history['loss'], label='train data')
plt.plot(modelHistory.history['val_loss'], label='test data')
plt.title('Pretrained-EfficientNetV2M Train/Test Loss')
plt.ylabel('Loss')
plt.xlabel('Number of Epochs')
plt.legend(loc="upper left")
plt.savefig('./Train-Test History/Loss/Pretrained-EfficientNetV2M-loss-Graph.png', bbox_inches = "tight")
plt.show()

# Plot history: Accuracy
plt.plot(modelHistory.history['categorical_accuracy'], label='train data')
plt.plot(modelHistory.history['val_categorical_accuracy'], label='test data')
plt.title('Pretrained-EfficientNetV2M Train/Test Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of Epochs')
plt.legend(loc="upper left")
plt.savefig('./Train-Test History/Accuracy/EfficientNetV2M-Accuracy-Graph.png', bbox_inches = "tight")
plt.show()

# %%
# Evaluate the Best Saved Model
model = tf.keras.models.load_model('/kaggle/working/Model/efficientnetv2-best-model.h5')
loss, accuracy, auc = model.evaluate(x=test_x, y=test_y_oneHot, batch_size=32, verbose=1)
print('Model Accuracy: {:0.2f} | Model AUC: {:0.2f} | Model Loss: {:0.4f}'.format(accuracy, auc, loss))
# Out:
# 8/8 [==============================] - 7s 190ms/step - loss: 1.0709 - categorical_accuracy: 0.5931 - auc: 0.7656
# Model Accuracy: 0.59 | Model AUC: 0.77 | Model Loss: 1.0709

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Purples')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('GroundTruths')
    plt.xlabel('Predictions \n Model Accuracy={:0.2f}% | Model Error={:0.2f}%'.format(accuracy*100, misclass*100))
    plt.savefig('./efficientenetv2-cm.png', bbox_inches = "tight")
    plt.show()


predictions = model.predict(x=test_x, batch_size=32)
predictions = tf.keras.backend.argmax(predictions, axis=-1)

cm = confusion_matrix(test_y, predictions)
classes = ['Normal', 'Pneumonia', 'COVID-19']
plot_confusion_matrix(cm=cm, normalize = False, target_names = classes, title= "Confusion Matrix (Pretrained EfficientNetV2M)")
# Out:
# 8/8 [==============================] - 6s 110ms/step

# %%
#Plot ROC Curve with Library
predictions = model.predict(x=test_x, batch_size=32)
# One can define colormap here
# cmap = mpl.colors.ListedColormap(['red', 'green', 'blue', 'cyan'])
scikitplot.metrics.plot_roc(y_true=test_y, y_probas=predictions, title='ROC Curves (Pretrained EfficientNetV2M)', plot_micro=False, plot_macro=False,
                            classes_to_plot=None, ax=None, figsize=(8, 6), cmap='Dark2', title_fontsize='large', text_fontsize='medium')
plt.savefig('./efficientnetv2-roc.png', bbox_inches = "tight")
plt.show()
# Out:
# 8/8 [==============================] - 1s 110ms/step
