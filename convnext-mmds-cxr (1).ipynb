# %%
# !pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
# import all libraries
# Train/Test Libraries

import os
import numpy as np
import tensorflow as tf
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import scikitplot
from sklearn.metrics import roc_curve, auc
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
dataDir = '/kaggle/input/mmds-cxr'
train_x = np.load(dataDir+'/train_images.npy')
train_y = np.load(dataDir+'/train_labels.npy')
test_x = np.load(dataDir+'/test_images.npy')
test_y = np.load(dataDir+'/test_labels.npy')

print('Training Images: {} | Test Images: {}'.format(train_x.shape, test_x.shape))
print('Training Labels: {} | Test Labels: {}'.format(train_y.shape, test_y.shape))

# Data Normalization

print('Train: {} , {} | Test: {} , {}'.format(train_x.min(), train_x.max(), test_x.min(), test_x.max()))

train_x/=255.0
test_x/=255.0

print('Train: {} , {} | Test: {} , {}'.format(train_x.min(), train_x.max(), test_x.min(), test_x.max()))
# Out:
# Training Images: (14925, 224, 224, 3) | Test Images: (231, 224, 224, 3)
# Training Labels: (14925,) | Test Labels: (231,)
# Train: 0.0 , 255.0 | Test: 0.0 , 255.0
# Train: 0.0 , 1.0 | Test: 0.0 , 1.0

# %%
# Class Mapping 
print('0:Normal | 1:Pneumonia | 2:COVID-19')

# Distribution of images in each class for Training-set
print(Counter(train_y))

# Distribution of images in each class for Test-set
print(Counter(test_y))

#Make Labels Categorical
train_y_oneHot = tf.one_hot(train_y, depth=3) 
test_y_oneHot = tf.one_hot(test_y, depth=3)

print('Training Labels: {} | Test Labels: {}'.format(train_y_oneHot.shape, test_y_oneHot.shape))
# Out:
# 0:Normal | 1:Pneumonia | 2:COVID-19
# Counter({0: 8751, 1: 5945, 2: 229})
# Counter({0: 100, 1: 100, 2: 31})
# Training Labels: (14925, 3) | Test Labels: (231, 3)

# %%
# initialize the training data augmentation object
trainAug = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=15, fill_mode="nearest")

def MobileNetV2_Model():
    # load the VGG16 network, ensuring the head FC layer sets are left off
    baseModel = tf.keras.applications.convnext.ConvNeXtBase(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
    # construct the head of the model that will be placed on top of the the base model
    output = baseModel.output
    output = tf.keras.layers.GlobalAveragePooling2D()(output)
    output = tf.keras.layers.Dense(1024, activation="relu")(output)
    output = tf.keras.layers.Dense(512, activation="relu")(output)
    output = tf.keras.layers.Dense(3, activation="softmax")(output)
    # place the head FC model on top of the base model (this will become the actual model we will train)
    model = tf.keras.Model(inputs=baseModel.input, outputs=output)
    # loop over all layers in the base model and freeze them so they will not be updated during the first training process
    for layer in baseModel.layers:
        layer.trainable = False
    return model

model = MobileNetV2_Model()
# compile our model
print("[INFO] compiling model...")
# initialize the initial learning rate, number of epochs to train for, and batch size
INIT_LR = 0.001
EPOCHS = 50
BATCHSIZE = 32 
optimizer = tf.keras.optimizers.Adam(lr=INIT_LR, weight_decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.AUC()])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 12s 0us/step
# [INFO] compiling model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  convnext_base_prestem_norm  (None, 224, 224, 3)          0         ['input_1[0][0]']
#  alization (Normalization)
#
#  convnext_base_stem (Sequen  (None, 56, 56, 128)          6528      ['convnext_base_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          6400      ['convnext_base_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          256       ['convnext_base_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          66048     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          0         ['convnext_base_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          65664     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          128       ['convnext_base_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          0         ['convnext_base_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 56, 56, 128)          0         ['convnext_base_stem[0][0]',
#  Lambda)                                                             'convnext_base_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          6400      ['tf.__operators__.add[0][0]']
#  k_1_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          256       ['convnext_base_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          66048     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          0         ['convnext_base_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          65664     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          128       ['convnext_base_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          0         ['convnext_base_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 56, 56, 128)          0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'convnext_base_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          6400      ['tf.__operators__.add_1[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          256       ['convnext_base_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          66048     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 512)          0         ['convnext_base_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          65664     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          128       ['convnext_base_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 56, 56, 128)          0         ['convnext_base_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 56, 56, 128)          0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 28, 28, 256)          131584    ['tf.__operators__.add_2[0][0]
#  _block_0 (Sequential)                                              ']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          12800     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          512       ['convnext_base_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         263168    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         0         ['convnext_base_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          262400    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          256       ['convnext_base_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          0         ['convnext_base_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 28, 28, 256)          0         ['convnext_base_downsampling_b
#  OpLambda)                                                          lock_0[0][0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          12800     ['tf.__operators__.add_3[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          512       ['convnext_base_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         263168    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         0         ['convnext_base_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          262400    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          256       ['convnext_base_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          0         ['convnext_base_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 28, 28, 256)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          12800     ['tf.__operators__.add_4[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          512       ['convnext_base_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         263168    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 1024)         0         ['convnext_base_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          262400    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          256       ['convnext_base_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 28, 28, 256)          0         ['convnext_base_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 28, 28, 256)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 14, 14, 512)          525312    ['tf.__operators__.add_5[0][0]
#  _block_1 (Sequential)                                              ']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 14, 14, 512)          0         ['convnext_base_downsampling_b
#  OpLambda)                                                          lock_1[0][0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_6[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 14, 14, 512)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_7[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 14, 14, 512)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_8[0][0]
#  k_3_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 14, 14, 512)          0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_9[0][0]
#  k_4_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_10[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_11[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_12[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_13[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_14[0][0
#  k_9_depthwise_conv (Conv2D                                         ]']
# ...
#  k_25_gelu (Activation)                                             25_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_25_pointwise_conv_2 (Den                                         25_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_25_layer_scale (LayerSca                                         25_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_25_identity (Activation)                                         25_layer_scale[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_30[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     25_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          25600     ['tf.__operators__.add_31[0][0
#  k_26_depthwise_conv (Conv2                                         ]']
#  D)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1024      ['convnext_base_stage_2_block_
#  k_26_layernorm (LayerNorma                                         26_depthwise_conv[0][0]']
#  lization)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_1 (Den                                         26_layernorm[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 2048)         0         ['convnext_base_stage_2_block_
#  k_26_gelu (Activation)                                             26_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          1049088   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_2 (Den                                         26_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          512       ['convnext_base_stage_2_block_
#  k_26_layer_scale (LayerSca                                         26_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 14, 14, 512)          0         ['convnext_base_stage_2_block_
#  k_26_identity (Activation)                                         26_layer_scale[0][0]']
#
#  tf.__operators__.add_32 (T  (None, 14, 14, 512)          0         ['tf.__operators__.add_31[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     26_identity[0][0]']
#
#  convnext_base_downsampling  (None, 7, 7, 1024)           2099200   ['tf.__operators__.add_32[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_33 (T  (None, 7, 7, 1024)           0         ['convnext_base_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_33[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_34 (T  (None, 7, 7, 1024)           0         ['tf.__operators__.add_33[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_34[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_35 (T  (None, 7, 7, 1024)           0         ['tf.__operators__.add_34[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  layer_normalization (Layer  (None, 7, 7, 1024)           2048      ['tf.__operators__.add_35[0][0
#  Normalization)                                                     ]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['layer_normalization[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)                 1049600   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 512)                  524800    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3)                    1539      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 89142403 (340.05 MB)
# Trainable params: 1575939 (6.01 MB)
# Non-trainable params: 87566464 (334.04 MB)
# __________________________________________________________________________________________________
# None

# %%
modelPath = '/kaggle/working/Model'
if not os.path.exists(modelPath):
    os.makedirs(modelPath)
    print('Model Directory Created')
else:
    print('Model Directory Already Exists')

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(modelPath+'/convnext-best-model.h5', monitor='val_categorical_accuracy',
                                                      verbose=1, save_best_only=True, mode='auto')

STEP_TRAIN = len(train_x) // BATCHSIZE
STEP_TEST = len(test_x) // BATCHSIZE
modelHistory = model.fit(trainAug.flow(train_x, train_y_oneHot, batch_size=BATCHSIZE), epochs=EPOCHS, verbose=1, callbacks=[model_checkpoint],
                         validation_data=(test_x, test_y_oneHot), shuffle = True, steps_per_epoch=STEP_TRAIN, validation_steps=STEP_TEST)
tf.keras.models.save_model(model, modelPath+'/convnext-model.h5', overwrite=True, include_optimizer=True, save_format=None,
                           signatures=None, options=None)
# Out:
# Model Directory Created
# Epoch 1/50
# 466/466 [==============================] - ETA: 0s - loss: 0.7206 - categorical_accuracy: 0.6208 - auc: 0.8301
# Epoch 1: val_categorical_accuracy improved from -inf to 0.58874, saving model to /kaggle/working/Model/convnext-best-model.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 466/466 [==============================] - 193s 361ms/step - loss: 0.7206 - categorical_accuracy: 0.6208 - auc: 0.8301 - val_loss: 1.1023 - val_categorical_accuracy: 0.5887 - val_auc: 0.7658
# Epoch 2/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6769 - categorical_accuracy: 0.6496 - auc: 0.8513
# Epoch 2: val_categorical_accuracy improved from 0.58874 to 0.59307, saving model to /kaggle/working/Model/convnext-best-model.h5
# 466/466 [==============================] - 163s 350ms/step - loss: 0.6769 - categorical_accuracy: 0.6496 - auc: 0.8513 - val_loss: 1.0029 - val_categorical_accuracy: 0.5931 - val_auc: 0.7808
# Epoch 3/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6579 - categorical_accuracy: 0.6696 - auc: 0.8642
# Epoch 3: val_categorical_accuracy improved from 0.59307 to 0.62771, saving model to /kaggle/working/Model/convnext-best-model.h5
# 466/466 [==============================] - 161s 344ms/step - loss: 0.6579 - categorical_accuracy: 0.6696 - auc: 0.8642 - val_loss: 1.0002 - val_categorical_accuracy: 0.6277 - val_auc: 0.7900
# Epoch 4/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6458 - categorical_accuracy: 0.6805 - auc: 0.8693
# Epoch 4: val_categorical_accuracy did not improve from 0.62771
# 466/466 [==============================] - 158s 338ms/step - loss: 0.6458 - categorical_accuracy: 0.6805 - auc: 0.8693 - val_loss: 0.9477 - val_categorical_accuracy: 0.6277 - val_auc: 0.8028
# Epoch 5/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6391 - categorical_accuracy: 0.6867 - auc: 0.8735
# Epoch 5: val_categorical_accuracy improved from 0.62771 to 0.65801, saving model to /kaggle/working/Model/convnext-best-model.h5
# 466/466 [==============================] - 158s 339ms/step - loss: 0.6391 - categorical_accuracy: 0.6867 - auc: 0.8735 - val_loss: 0.9042 - val_categorical_accuracy: 0.6580 - val_auc: 0.8104
# Epoch 6/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6318 - categorical_accuracy: 0.6905 - auc: 0.8777
# Epoch 6: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 159s 339ms/step - loss: 0.6318 - categorical_accuracy: 0.6905 - auc: 0.8777 - val_loss: 1.0129 - val_categorical_accuracy: 0.6234 - val_auc: 0.8060
# Epoch 7/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6236 - categorical_accuracy: 0.6985 - auc: 0.8814
# Epoch 7: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 158s 339ms/step - loss: 0.6236 - categorical_accuracy: 0.6985 - auc: 0.8814 - val_loss: 0.9793 - val_categorical_accuracy: 0.6407 - val_auc: 0.8005
# Epoch 8/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6230 - categorical_accuracy: 0.6991 - auc: 0.8813
# Epoch 8: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 159s 341ms/step - loss: 0.6230 - categorical_accuracy: 0.6991 - auc: 0.8813 - val_loss: 1.0267 - val_categorical_accuracy: 0.6450 - val_auc: 0.8042
# Epoch 9/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6206 - categorical_accuracy: 0.7010 - auc: 0.8823
# Epoch 9: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 160s 342ms/step - loss: 0.6206 - categorical_accuracy: 0.7010 - auc: 0.8823 - val_loss: 0.9756 - val_categorical_accuracy: 0.6061 - val_auc: 0.7904
# Epoch 10/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6158 - categorical_accuracy: 0.7037 - auc: 0.8848
# Epoch 10: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 159s 340ms/step - loss: 0.6158 - categorical_accuracy: 0.7037 - auc: 0.8848 - val_loss: 1.0533 - val_categorical_accuracy: 0.6494 - val_auc: 0.8112
# Epoch 11/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6108 - categorical_accuracy: 0.7098 - auc: 0.8873
# Epoch 11: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 159s 340ms/step - loss: 0.6108 - categorical_accuracy: 0.7098 - auc: 0.8873 - val_loss: 0.9347 - val_categorical_accuracy: 0.6494 - val_auc: 0.8092
# Epoch 12/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6116 - categorical_accuracy: 0.7064 - auc: 0.8865
# Epoch 12: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 159s 340ms/step - loss: 0.6116 - categorical_accuracy: 0.7064 - auc: 0.8865 - val_loss: 0.9228 - val_categorical_accuracy: 0.6494 - val_auc: 0.8032
# Epoch 13/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6003 - categorical_accuracy: 0.7203 - auc: 0.8923
# Epoch 13: val_categorical_accuracy did not improve from 0.65801
# 466/466 [==============================] - 158s 339ms/step - loss: 0.6003 - categorical_accuracy: 0.7203 - auc: 0.8923 - val_loss: 0.9169 - val_categorical_accuracy: 0.6537 - val_auc: 0.8097
# Epoch 14/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6105 - categorical_accuracy: 0.7120 - auc: 0.8875
# Epoch 14: val_categorical_accuracy improved from 0.65801 to 0.66234, saving model to /kaggle/working/Model/convnext-best-model.h5
# 466/466 [==============================] - 160s 342ms/step - loss: 0.6105 - categorical_accuracy: 0.7120 - auc: 0.8875 - val_loss: 0.9745 - val_categorical_accuracy: 0.6623 - val_auc: 0.8116
# Epoch 15/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5988 - categorical_accuracy: 0.7172 - auc: 0.8919
# Epoch 15: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5988 - categorical_accuracy: 0.7172 - auc: 0.8919 - val_loss: 1.0554 - val_categorical_accuracy: 0.6494 - val_auc: 0.8093
# Epoch 16/50
# 466/466 [==============================] - ETA: 0s - loss: 0.6023 - categorical_accuracy: 0.7146 - auc: 0.8907
# Epoch 16: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 341ms/step - loss: 0.6023 - categorical_accuracy: 0.7146 - auc: 0.8907 - val_loss: 1.0416 - val_categorical_accuracy: 0.6450 - val_auc: 0.8219
# Epoch 17/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5996 - categorical_accuracy: 0.7221 - auc: 0.8926
# Epoch 17: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 161s 345ms/step - loss: 0.5996 - categorical_accuracy: 0.7221 - auc: 0.8926 - val_loss: 0.9501 - val_categorical_accuracy: 0.6364 - val_auc: 0.8231
# Epoch 18/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5957 - categorical_accuracy: 0.7226 - auc: 0.8935
# Epoch 18: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 340ms/step - loss: 0.5957 - categorical_accuracy: 0.7226 - auc: 0.8935 - val_loss: 1.0283 - val_categorical_accuracy: 0.6190 - val_auc: 0.7972
# Epoch 19/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5974 - categorical_accuracy: 0.7201 - auc: 0.8927
# Epoch 19: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5974 - categorical_accuracy: 0.7201 - auc: 0.8927 - val_loss: 1.0299 - val_categorical_accuracy: 0.6147 - val_auc: 0.7971
# Epoch 20/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5936 - categorical_accuracy: 0.7225 - auc: 0.8943
# Epoch 20: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5936 - categorical_accuracy: 0.7225 - auc: 0.8943 - val_loss: 0.9543 - val_categorical_accuracy: 0.6320 - val_auc: 0.8233
# Epoch 21/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5896 - categorical_accuracy: 0.7234 - auc: 0.8959
# Epoch 21: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 338ms/step - loss: 0.5896 - categorical_accuracy: 0.7234 - auc: 0.8959 - val_loss: 0.9877 - val_categorical_accuracy: 0.6450 - val_auc: 0.8207
# Epoch 22/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5894 - categorical_accuracy: 0.7264 - auc: 0.8961
# Epoch 22: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5894 - categorical_accuracy: 0.7264 - auc: 0.8961 - val_loss: 1.0766 - val_categorical_accuracy: 0.6190 - val_auc: 0.8176
# Epoch 23/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5867 - categorical_accuracy: 0.7287 - auc: 0.8972
# Epoch 23: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 338ms/step - loss: 0.5867 - categorical_accuracy: 0.7287 - auc: 0.8972 - val_loss: 1.0018 - val_categorical_accuracy: 0.6494 - val_auc: 0.8035
# Epoch 24/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5883 - categorical_accuracy: 0.7277 - auc: 0.8965
# Epoch 24: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 338ms/step - loss: 0.5883 - categorical_accuracy: 0.7277 - auc: 0.8965 - val_loss: 1.0133 - val_categorical_accuracy: 0.6364 - val_auc: 0.8201
# Epoch 25/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5885 - categorical_accuracy: 0.7269 - auc: 0.8962
# Epoch 25: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5885 - categorical_accuracy: 0.7269 - auc: 0.8962 - val_loss: 0.9025 - val_categorical_accuracy: 0.6320 - val_auc: 0.8196
# Epoch 26/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5862 - categorical_accuracy: 0.7287 - auc: 0.8975
# Epoch 26: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5862 - categorical_accuracy: 0.7287 - auc: 0.8975 - val_loss: 1.0120 - val_categorical_accuracy: 0.6320 - val_auc: 0.8199
# Epoch 27/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5851 - categorical_accuracy: 0.7270 - auc: 0.8979
# Epoch 27: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5851 - categorical_accuracy: 0.7270 - auc: 0.8979 - val_loss: 1.0086 - val_categorical_accuracy: 0.6190 - val_auc: 0.7993
# Epoch 28/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5857 - categorical_accuracy: 0.7286 - auc: 0.8974
# Epoch 28: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5857 - categorical_accuracy: 0.7286 - auc: 0.8974 - val_loss: 1.0006 - val_categorical_accuracy: 0.6537 - val_auc: 0.8241
# Epoch 29/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5846 - categorical_accuracy: 0.7273 - auc: 0.8976
# Epoch 29: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 340ms/step - loss: 0.5846 - categorical_accuracy: 0.7273 - auc: 0.8976 - val_loss: 0.8953 - val_categorical_accuracy: 0.6623 - val_auc: 0.8054
# Epoch 30/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5798 - categorical_accuracy: 0.7358 - auc: 0.9003
# Epoch 30: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 340ms/step - loss: 0.5798 - categorical_accuracy: 0.7358 - auc: 0.9003 - val_loss: 1.0264 - val_categorical_accuracy: 0.6450 - val_auc: 0.8208
# Epoch 31/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5838 - categorical_accuracy: 0.7340 - auc: 0.8987
# Epoch 31: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5838 - categorical_accuracy: 0.7340 - auc: 0.8987 - val_loss: 0.9979 - val_categorical_accuracy: 0.5974 - val_auc: 0.7762
# Epoch 32/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5810 - categorical_accuracy: 0.7293 - auc: 0.8993
# Epoch 32: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5810 - categorical_accuracy: 0.7293 - auc: 0.8993 - val_loss: 0.9102 - val_categorical_accuracy: 0.6450 - val_auc: 0.8248
# Epoch 33/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5851 - categorical_accuracy: 0.7293 - auc: 0.8977
# Epoch 33: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 161s 345ms/step - loss: 0.5851 - categorical_accuracy: 0.7293 - auc: 0.8977 - val_loss: 0.9177 - val_categorical_accuracy: 0.6623 - val_auc: 0.8181
# Epoch 34/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5741 - categorical_accuracy: 0.7416 - auc: 0.9025
# Epoch 34: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5741 - categorical_accuracy: 0.7416 - auc: 0.9025 - val_loss: 1.0465 - val_categorical_accuracy: 0.5887 - val_auc: 0.7789
# Epoch 35/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5821 - categorical_accuracy: 0.7311 - auc: 0.8984
# Epoch 35: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 160s 342ms/step - loss: 0.5821 - categorical_accuracy: 0.7311 - auc: 0.8984 - val_loss: 1.0071 - val_categorical_accuracy: 0.6494 - val_auc: 0.8265
# Epoch 36/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5759 - categorical_accuracy: 0.7336 - auc: 0.9011
# Epoch 36: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 160s 343ms/step - loss: 0.5759 - categorical_accuracy: 0.7336 - auc: 0.9011 - val_loss: 1.0428 - val_categorical_accuracy: 0.6364 - val_auc: 0.8049
# Epoch 37/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5808 - categorical_accuracy: 0.7344 - auc: 0.8994
# Epoch 37: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 341ms/step - loss: 0.5808 - categorical_accuracy: 0.7344 - auc: 0.8994 - val_loss: 0.9354 - val_categorical_accuracy: 0.6494 - val_auc: 0.8204
# Epoch 38/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5746 - categorical_accuracy: 0.7337 - auc: 0.9019
# Epoch 38: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 161s 344ms/step - loss: 0.5746 - categorical_accuracy: 0.7337 - auc: 0.9019 - val_loss: 1.0224 - val_categorical_accuracy: 0.6364 - val_auc: 0.7981
# Epoch 39/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5759 - categorical_accuracy: 0.7387 - auc: 0.9014
# Epoch 39: val_categorical_accuracy did not improve from 0.66234
# 466/466 [==============================] - 159s 341ms/step - loss: 0.5759 - categorical_accuracy: 0.7387 - auc: 0.9014 - val_loss: 0.9975 - val_categorical_accuracy: 0.6450 - val_auc: 0.8197
# Epoch 40/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5761 - categorical_accuracy: 0.7379 - auc: 0.9014
# Epoch 40: val_categorical_accuracy improved from 0.66234 to 0.67532, saving model to /kaggle/working/Model/convnext-best-model.h5
# 466/466 [==============================] - 162s 347ms/step - loss: 0.5761 - categorical_accuracy: 0.7379 - auc: 0.9014 - val_loss: 0.9520 - val_categorical_accuracy: 0.6753 - val_auc: 0.8145
# Epoch 41/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5794 - categorical_accuracy: 0.7352 - auc: 0.9001
# Epoch 41: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5794 - categorical_accuracy: 0.7352 - auc: 0.9001 - val_loss: 0.9841 - val_categorical_accuracy: 0.6320 - val_auc: 0.8167
# Epoch 42/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5809 - categorical_accuracy: 0.7332 - auc: 0.8995
# Epoch 42: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 159s 340ms/step - loss: 0.5809 - categorical_accuracy: 0.7332 - auc: 0.8995 - val_loss: 0.9236 - val_categorical_accuracy: 0.6710 - val_auc: 0.8139
# Epoch 43/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5762 - categorical_accuracy: 0.7386 - auc: 0.9015
# Epoch 43: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 159s 341ms/step - loss: 0.5762 - categorical_accuracy: 0.7386 - auc: 0.9015 - val_loss: 1.0812 - val_categorical_accuracy: 0.6494 - val_auc: 0.8215
# Epoch 44/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5737 - categorical_accuracy: 0.7387 - auc: 0.9021
# Epoch 44: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 159s 341ms/step - loss: 0.5737 - categorical_accuracy: 0.7387 - auc: 0.9021 - val_loss: 1.0459 - val_categorical_accuracy: 0.6537 - val_auc: 0.8013
# Epoch 45/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5730 - categorical_accuracy: 0.7352 - auc: 0.9022
# Epoch 45: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 158s 338ms/step - loss: 0.5730 - categorical_accuracy: 0.7352 - auc: 0.9022 - val_loss: 1.1561 - val_categorical_accuracy: 0.6017 - val_auc: 0.7877
# Epoch 46/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5722 - categorical_accuracy: 0.7369 - auc: 0.9028
# Epoch 46: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 160s 343ms/step - loss: 0.5722 - categorical_accuracy: 0.7369 - auc: 0.9028 - val_loss: 0.9825 - val_categorical_accuracy: 0.6537 - val_auc: 0.8219
# Epoch 47/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5653 - categorical_accuracy: 0.7443 - auc: 0.9053
# Epoch 47: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 158s 338ms/step - loss: 0.5653 - categorical_accuracy: 0.7443 - auc: 0.9053 - val_loss: 0.9343 - val_categorical_accuracy: 0.6364 - val_auc: 0.8172
# Epoch 48/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5644 - categorical_accuracy: 0.7466 - auc: 0.9059
# Epoch 48: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5644 - categorical_accuracy: 0.7466 - auc: 0.9059 - val_loss: 0.9326 - val_categorical_accuracy: 0.6580 - val_auc: 0.8210
# Epoch 49/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5661 - categorical_accuracy: 0.7389 - auc: 0.9046
# Epoch 49: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 158s 339ms/step - loss: 0.5661 - categorical_accuracy: 0.7389 - auc: 0.9046 - val_loss: 0.9428 - val_categorical_accuracy: 0.6407 - val_auc: 0.8028
# Epoch 50/50
# 466/466 [==============================] - ETA: 0s - loss: 0.5692 - categorical_accuracy: 0.7407 - auc: 0.9036
# Epoch 50: val_categorical_accuracy did not improve from 0.67532
# 466/466 [==============================] - 160s 342ms/step - loss: 0.5692 - categorical_accuracy: 0.7407 - auc: 0.9036 - val_loss: 0.9557 - val_categorical_accuracy: 0.6277 - val_auc: 0.8123
# /tmp/ipykernel_42/3691538729.py:15: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   tf.keras.models.save_model(model, modelPath+'/convnext-model.h5', overwrite=True, include_optimizer=True, save_format=None,

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
import matplotlib.pyplot as plt
losshistoryPath = './Train-Test History/Loss'
acchistoryPath = './Train-Test History/Accuracy'
if not os.path.exists(losshistoryPath) or not os.path.exists(acchistoryPath):
    os.makedirs(losshistoryPath)
    os.makedirs(acchistoryPath)
  
# Plot history: Loss
plt.plot(modelHistory.history['loss'], label='train data')
plt.plot(modelHistory.history['val_loss'], label='test data')
plt.title('Pretrained-ConvNeXt Train/Test Loss')
plt.ylabel('Loss')
plt.xlabel('Number of Epochs')
plt.legend(loc="upper left")
plt.savefig('./Train-Test History/Loss/Pretrained-ConvNeXt-loss-Graph.png', bbox_inches = "tight")
plt.show()

# Plot history: Accuracy
plt.plot(modelHistory.history['categorical_accuracy'], label='train data')
plt.plot(modelHistory.history['val_categorical_accuracy'], label='test data')
plt.title('Pretrained-ConvNeXt Train/Test Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of Epochs')
plt.legend(loc="upper left")
plt.savefig('./Train-Test History/Accuracy/ConvNeXt-Accuracy-Graph.png', bbox_inches = "tight")
plt.show()

# %%
class StochasticDepth(tf.keras.layers.Layer):
    """Stochastic Depth module.

    It performs batch-wise dropping rather than sample-wise. In libraries like
    `timm`, it's similar to `DropPath` layers that drops residual paths
    sample-wise.

    References:
      - https://github.com/rwightman/pytorch-image-models

    Args:
      drop_path_rate (float): Probability of dropping paths. Should be within
        [0, 1].

    Returns:
      Tensor either with the residual path dropped or kept.
    """

    def __init__(self, drop_path_rate, **kwargs):
        super().__init__(**kwargs)
        self.drop_path_rate = drop_path_rate

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_path_rate
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

    def get_config(self):
        config = super().get_config()
        config.update({"drop_path_rate": self.drop_path_rate})
        return config

# %%
class LayerScale(tf.keras.layers.Layer):
    """Layer scale module.

    References:
      - https://arxiv.org/abs/2103.17239

    Args:
      init_values (float): Initial value for layer scale. Should be within
        [0, 1].
      projection_dim (int): Projection dimensionality.

    Returns:
      Tensor multiplied to the scale.
    """

    def __init__(self, init_values, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.init_values = init_values
        self.projection_dim = projection_dim

    def build(self, input_shape):
        self.gamma = tf.Variable(
            self.init_values * tf.ones((self.projection_dim,))
        )

    def call(self, x):
        return x * self.gamma

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "init_values": self.init_values,
                "projection_dim": self.projection_dim,
            }
        )
        return config

# %%
# Evaluate the Best Saved Model
model = tf.keras.models.load_model('/kaggle/working/Model/convnext-best-model.h5', custom_objects={ "LayerScale": LayerScale, "StochasticDepth": StochasticDepth })
loss, accuracy, auc = model.evaluate(x=test_x, y=test_y_oneHot, batch_size=32, verbose=1)
print('Model Accuracy: {:0.2f} | Model AUC: {:0.2f} | Model Loss: {:0.4f}'.format(accuracy, auc, loss))
# Out:
# 8/8 [==============================] - 12s 743ms/step - loss: 0.9520 - categorical_accuracy: 0.6753 - auc: 0.8145
# Model Accuracy: 0.68 | Model AUC: 0.81 | Model Loss: 0.9520

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Purples')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('GroundTruths')
    plt.xlabel('Predictions \n Model Accuracy={:0.2f}% | Model Error={:0.2f}%'.format(accuracy*100, misclass*100))
    plt.savefig('./convnext-cm.png', bbox_inches = "tight")
    plt.show()


predictions = model.predict(x=test_x, batch_size=32)
predictions = tf.keras.backend.argmax(predictions, axis=-1)

cm = confusion_matrix(test_y, predictions)
classes = ['Normal', 'Pneumonia', 'COVID-19']
plot_confusion_matrix(cm=cm, normalize = False, target_names = classes, title= "Confusion Matrix (Pretrained ConvNeXt)")
# Out:
# 8/8 [==============================] - 6s 292ms/step

# %%
#Plot ROC Curve with Library
predictions = model.predict(x=test_x, batch_size=32)
# One can define colormap here
# cmap = mpl.colors.ListedColormap(['red', 'green', 'blue', 'cyan'])
scikitplot.metrics.plot_roc(y_true=test_y, y_probas=predictions, title='ROC Curves (Pretrained ConvNeXt)', plot_micro=False, plot_macro=False,
                            classes_to_plot=None, ax=None, figsize=(8, 6), cmap='Dark2', title_fontsize='large', text_fontsize='medium')
plt.savefig('./convnext-roc.png', bbox_inches = "tight")
plt.show()
# Out:
# 8/8 [==============================] - 2s 291ms/step
